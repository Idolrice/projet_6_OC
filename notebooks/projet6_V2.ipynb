# %% [markdown]
# * erp = pd.read_csv("ERP P6.csv")
# * web = pd.read_csv(".csv")
# * caract_vin = pd.read_csv(".csv")
# * liaison = pd.read_csv(".csv")

# %% [markdown]
# #Start fichier CSV ERP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
erp = pd.read_csv("../data/ERP P6.csv")

# %%
erp.tail(10)
# Out:
#      product_id  onsale_web price  stock_quantity stock_status
# 815        7194           0    31               5      instock
# 816        7195           0    21               1      instock
# 817        7196           0    31              55      instock
# 818        7200           0    31               6      instock
# 819        7201           0    31              18      instock
# 820        7203           0    45              30      instock
# 821        7204           0    45               9      instock
# 822        7247           1  54,8              23      instock
# 823        7329           0  26,5              14      instock
# 824        7338           1  16,3              45      instock

# %%
erp.sample(10)
# Out:
#      product_id  onsale_web price  stock_quantity stock_status
# 467        5010           1  55,6              17      instock
# 518        5486           1  49,5               5      instock
# 507        5446           1  16,2              30      instock
# 353        4739           1   7,4              50      instock
# 133        4211           1  48,5               0   outofstock
# 755        6664           1  35,6              38      instock
# 769        6884           1  46,5              12      instock
# 88         4159           1   9,3               0   outofstock
# 390        4863           1   8,2               0   outofstock
# 698        6127           1  10,6              66      instock

# %%
erp.shape
# Out:
# (825, 5)

# %%
erp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      825 non-null    int64
#  1   onsale_web      825 non-null    int64
#  2   price           825 non-null    object
#  3   stock_quantity  825 non-null    int64
#  4   stock_status    825 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 32.4+ KB

# %%
erp.dtypes.value_counts()
# Out:
# int64     3
# object    2
# Name: count, dtype: int64

# %%
erp.isna().sum()
# Out:
# product_id        0
# onsale_web        0
# price             0
# stock_quantity    0
# stock_status      0
# dtype: int64

# %%
erp.isna().mean().round(2)
# Out:
# product_id        0.0
# onsale_web        0.0
# price             0.0
# stock_quantity    0.0
# stock_status      0.0
# dtype: float64

# %%
erp.nunique()
#PK product_id,
#type Boléen : onsale_web / stock_status = erp['onsale_web','stock_status'].astype(bool)
#type Float : price = erp['price'].astype(float)
# Out:
# product_id        825
# onsale_web          2
# price             381
# stock_quantity    128
# stock_status        2
# dtype: int64

# %% [markdown]
# # Start fichier CSV caracteristiques_vins

# %%
carat_vin = pd.read_csv("../data/Caractéristiques_vins P6 - caracteristiques_vins.csv")

# %%
carat_vin.tail(10)
# Out:
#                                              post_name   poids  \
# 601   emile-boeckel-cremant-chardonnay-extra-brut-2016  1.5 kg
# 602                          chateau-simone-blanc-2017  1.5 kg
# 603            domino-romano-ribera-del-duero-rdr-2015  1.5 kg
# 604                        gratavinum-priorat-gv5-2011  1.5 kg
# 605                   gratavinum-priorat-2%cf%80r-2017  1.5 kg
# 606    chateau-jean-faure-saint-emilion-grand-cru-2016  1.5 kg
# 607                    mouthes-le-bihan-aime-chai-2015  1.5 kg
# 608         camin-larredya-jurancon-sec-la-virada-2018  1.5 kg
# 609             jamet-cote-rotie-fructus-voluptas-2018  1.5 kg
# 610  domaine-saint-nicolas-fiefs-vendeens-blanc-les...  1.5 kg
#
#                  Région             Domaine                     Appellation  \
# 601              Alsace       Emile Boeckel                Crémant d'Alsace
# 602            Provence      Château Simone                         Palette
# 603             Espagne       Domino Romano                Ribera Del Duero
# 604             Espagne          Gratavinum                         Priorat
# 605             Espagne          Gratavinum                         Priorat
# 606            Bordeaux  Château Jean Faure  Saint-Emilion Grand Cru Classé
# 607           Sud Ouest    Mouthes Le Bihan                  Côtes-de-Duras
# 608           Sud Ouest      Camin Larredya                        Jurançon
# 609               Rhône               Jamet                      Côte Rôtie
# 610  Vallée de la Loire       Saint-Nicolas                             NaN
#
#     Couleur                    Cépage (decider avec ou sans %)  Millésime  \
# 601   Blanc                                         Chardonnay        NaN
# 602   Blanc  Bourboulenc, Clairette, Grenache Blanc, Muscat...     2018.0
# 603   Rouge                                         Tinto Fino     2015.0
# 604   Rouge             Cabernet Sauvignon, Carignan, Grenache     2013.0
# 605   Rouge      Cabernet Sauvignon, Carignan, Grenache, Syrah     2018.0
# 606   Rouge                     Cabernet Franc, Malbec, Merlot     2016.0
# 607   Rouge                 Cabernet Sauvignon, Malbec, Merlot     2016.0
# 608   Blanc          Gros Manseng, Petit Courbu, Petit Manseng     2018.0
# 609   Rouge                                              Syrah     2020.0
# 610   Blanc                                 Chardonnay, Chenin     2019.0
#
#            Garde Contenance Degré d'alcool Température dégustation  \
# 601      3-5 ans       75cl            12%                     9°C
# 602  10 ans et +       75cl         13,50%                    12°C
# 603  10 ans et +       75cl         14,50%                    18°C
# 604  10 ans et +       75cl         14,50%                    16°C
# 605  10 ans et +       75cl         13,50%                    16°C
# 606  15 ans et +       75cl         13,50%                    18°C
# 607      4-7 ans       75cl         13,50%                    14°C
# 608     8-10 ans       75cl            14%                    11°C
# 609  10 ans et +       75cl            13%                    16°C
# 610      3-5 ans       75cl            14%                    12°C
#
#                                          Alliance mets
# 601              Apéritif, Fromages, Huîtres, Poissons
# 602  Anchoïade de légumes, Carpaccio de poisson, Fa...
# 603            Agneau, Canard, Grillades, Viande rouge
# 604            Agneau, Canard, Grillades, Viande rouge
# 605            Agneau, Canard, Grillades, Viande rouge
# 606           Filet de boeuf, Gibier, Magret de Canard
# 607  Boeuf aux carottes, Pommes de terre sarladaise...
# 608    Charcuterie, Fromages, Poissons, Viande Blanche
# 609               Agneau, Gibier, Pigeon, Viande rouge
# 610                      Crustacés, Fromages, Poissons

# %%
carat_vin.sample(10)
# Out:
#                                              post_name   poids  \
# 535  domaine-labranche-laffont-madiran-vieilles-vig...  1.5 kg
# 574  le-pas-de-lescalette-igp-pays-dherault-les-cla...  1.5 kg
# 376                        chateau-cordet-margaux-2013  1.5 kg
# 173                   la-tour-du-bon-bandol-blanc-2019  1.5 kg
# 461  philippe-nusswitz-duche-uzes-orenia-blanc-rese...  1.5 kg
# 585                     clos-du-mont-olivet-lirac-2017  1.5 kg
# 472      domaine-de-lhortus-herault-loup-bergerie-2018  1.5 kg
# 194                           whisky-wemyss-spice-king  1.5 kg
# 320  maurice-schoech-riesling-grand-cru-kaefferkopf...  1.5 kg
# 386  domaine-des-comtes-lafon-monthelie-1er-cru-les...  1.5 kg
#
#                    Région                        Domaine        Appellation  \
# 535             Sud Ouest              Labranche Laffont            Madiran
# 574  Languedoc-Roussillon          Le Pas de l'Escalette     Pays d'Hérault
# 376              Bordeaux                 Château Cordet            Margaux
# 173              Provence                 La Tour Du Bon             Bandol
# 461  Languedoc-Roussillon  Les Vins de Philippe Nusswitz       Duché d'Uzès
# 585                 Rhône            Clos Du Mont-Olivet              Lirac
# 472  Languedoc-Roussillon            Domaine de l'Hortus     Pays d'Hérault
# 194                   NaN                            NaN                NaN
# 320                Alsace                Maurice Schoech   Alsace Grand Cru
# 386             Bourgogne       Domaine des Comtes Lafon  Monthélie 1er Cru
#
#     Couleur                    Cépage (decider avec ou sans %)  Millésime  \
# 535   Rouge                                             Tannat     2018.0
# 574   Blanc  Carignan Blanc, Grenache Blanc, Grenache Gris,...     2020.0
# 376   Rouge  Cabernet Franc, Cabernet Sauvignon, Merlot, Pe...     2017.0
# 173   Blanc                       Clairette, Rolle, Ugni Blanc     2021.0
# 461   Blanc                      Marsanne, Roussanne, Viognier     2019.0
# 585   Rouge                          Cinsault, Grenache, Syrah     2019.0
# 472   Rouge                          Cinsault, Grenache, Syrah     2020.0
# 194     NaN                                                NaN        NaN
# 320   Blanc                                           Riesling     2019.0
# 386   Rouge                                         Pinot Noir     2017.0
#
#         Garde Contenance Degré d'alcool Température dégustation  \
# 535  8-10 ans       75cl         14,50%                    16°C
# 574   4-7 ans       75cl         12,50%                    12°C
# 376   6-8 ans       75cl            13%                    16°C
# 173   3-5 ans       75cl            13%                    11°C
# 461   3-5 ans       75cl         13,50%                    12°C
# 585   4-7 ans       75cl         14,50%                    15°C
# 472     3 ans       75cl         12,50%                    15°C
# 194       NaN       70cl            46%                     NaN
# 320  8-10 ans       75cl            13%                    12°C
# 386  8-10 ans       75cl            NaN                    15°C
#
#                                          Alliance mets
# 535                       Canard, Gibier, Viande rouge
# 574                     Veau, Viande Blanche, Volaille
# 376            Canard, Gibier, Grillades, Viande rouge
# 173  Apéritif, Fromage de chèvre, Poisson grillé, S...
# 461  Apéritif, Poisson grillé, Viande Blanche, Vola...
# 585                          Charcuterie, Viande rouge
# 472                   Apéritif, Charcuterie, Grillades
# 194                                                NaN
# 320  Choucroute, Crustacés, Huîtres, Poissons, Vola...
# 386            Filet de Chevreuil, Lapin, Viande rouge

# %%
carat_vin.shape
# Out:
# (611, 13)

# %%
carat_vin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   post_name                        611 non-null    object
#  1   poids                            611 non-null    object
#  2   Région                           586 non-null    object
#  3   Domaine                          577 non-null    object
#  4   Appellation                      559 non-null    object
#  5   Couleur                          566 non-null    object
#  6   Cépage (decider avec ou sans %)  571 non-null    object
#  7   Millésime                        541 non-null    float64
#  8   Garde                            569 non-null    object
#  9   Contenance                       611 non-null    object
#  10  Degré d'alcool                   586 non-null    object
#  11  Température dégustation          574 non-null    object
#  12  Alliance mets                    574 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 62.2+ KB

# %%
carat_vin.dtypes
# Out:
# post_name                           object
# poids                               object
# Région                              object
# Domaine                             object
# Appellation                         object
# Couleur                             object
# Cépage (decider avec ou sans %)     object
# Millésime                          float64
# Garde                               object
# Contenance                          object
# Degré d'alcool                      object
# Température dégustation             object
# Alliance mets                       object
# dtype: object

# %%
carat_vin.dtypes.value_counts()
# Out:
# object     12
# float64     1
# Name: count, dtype: int64

# %%
carat_vin.isna()
# Out:
#      post_name  poids  Région  Domaine  Appellation  Couleur  \
# 0        False  False   False    False        False    False
# 1        False  False   False    False        False    False
# 2        False  False   False    False        False    False
# 3        False  False   False    False        False    False
# 4        False  False   False    False        False    False
# ..         ...    ...     ...      ...          ...      ...
# 606      False  False   False    False        False    False
# 607      False  False   False    False        False    False
# 608      False  False   False    False        False    False
# 609      False  False   False    False        False    False
# 610      False  False   False    False         True    False
#
#      Cépage (decider avec ou sans %)  Millésime  Garde  Contenance  \
# 0                              False      False  False       False
# 1                              False      False  False       False
# 2                              False      False  False       False
# 3                              False      False  False       False
# 4                              False      False  False       False
# ..                               ...        ...    ...         ...
# 606                            False      False  False       False
# 607                            False      False  False       False
# 608                            False      False  False       False
# 609                            False      False  False       False
# 610                            False      False  False       False
#
#      Degré d'alcool  Température dégustation  Alliance mets
# 0             False                    False          False
# 1             False                    False          False
# 2             False                    False          False
# 3             False                    False          False
# 4             False                    False          False
# ..              ...                      ...            ...
# 606           False                    False          False
# 607           False                    False          False
# 608           False                    False          False
# 609           False                    False          False
# 610           False                    False          False
#
# [611 rows x 13 columns]

# %%
carat_vin.isna().sum()
# Out:
# post_name                           0
# poids                               0
# Région                             25
# Domaine                            34
# Appellation                        52
# Couleur                            45
# Cépage (decider avec ou sans %)    40
# Millésime                          70
# Garde                              42
# Contenance                          0
# Degré d'alcool                     25
# Température dégustation            37
# Alliance mets                      37
# dtype: int64

# %%
carat_vin.isna().mean().round(2)
# Out:
# post_name                          0.00
# poids                              0.00
# Région                             0.04
# Domaine                            0.06
# Appellation                        0.09
# Couleur                            0.07
# Cépage (decider avec ou sans %)    0.07
# Millésime                          0.11
# Garde                              0.07
# Contenance                         0.00
# Degré d'alcool                     0.04
# Température dégustation            0.06
# Alliance mets                      0.06
# dtype: float64

# %%
carat_vin.isna().mean().round(2).sort_values(ascending = False)
# Out:
# Millésime                          0.11
# Appellation                        0.09
# Couleur                            0.07
# Cépage (decider avec ou sans %)    0.07
# Garde                              0.07
# Domaine                            0.06
# Température dégustation            0.06
# Alliance mets                      0.06
# Région                             0.04
# Degré d'alcool                     0.04
# post_name                          0.00
# poids                              0.00
# Contenance                         0.00
# dtype: float64

# %%
carat_vin.isna().mean(axis=1).round(2).sort_values(ascending = False)
# Out:
# 198    0.69
# 527    0.69
# 484    0.69
# 201    0.69
# 200    0.69
#        ...
# 218    0.00
# 217    0.00
# 216    0.00
# 215    0.00
# 305    0.00
# Length: 611, dtype: float64

# %%
tnp = carat_vin.isna().mean(axis=1).round(2).sort_values(ascending = False).value_counts()
tnp
# Out:
# 0.00    493
# 0.08     70
# 0.62     20
# 0.69     17
# 0.15      9
# 0.23      2
# Name: count, dtype: int64

# %%
sns.heatmap(carat_vin.isna())
# Out:
# <Axes: >

# %%
carat_vin.post_name.nunique()
# Out:
# 611

# %%
carat_vin.nunique()
# Out:
# post_name                          611
# poids                                3
# Région                              17
# Domaine                            135
# Appellation                        174
# Couleur                              3
# Cépage (decider avec ou sans %)    195
# Millésime                           15
# Garde                               16
# Contenance                           7
# Degré d'alcool                      24
# Température dégustation             12
# Alliance mets                      351
# dtype: int64

# %%
# la même chose pour 3 fichiers / (+ rename + suppr index 70% empty) = carat_vin.drop('')
#PK : post_name
#Millésime ? INT

# %% [markdown]
# #Start fichier CSV WEB

# %%
web =pd.read_csv("../data/WEB P6.csv")
web.head()
# Out:
#                    sku  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros        0             0             0             0.0
# 1                15298        0             0             0             0.0
# 2                15296        0             0             0             0.0
# 3                15300        0             0             0             0.0
# 4                19814        0             0             0             0.0
#
#    total_sales tax_status  tax_class  post_author            post_date  ...  \
# 0         10.0    taxable        NaN          1.0  2018-06-01 13:53:46  ...
# 1          6.0    taxable        NaN          2.0  2018-02-08 12:58:52  ...
# 2          0.0    taxable        NaN          2.0  2018-02-08 13:49:41  ...
# 3          0.0    taxable        NaN          2.0  2018-02-08 14:08:36  ...
# 4          3.0    taxable        NaN          2.0  2018-02-09 14:01:05  ...
#
#                                            post_name        post_modified  \
# 0                             bon-cadeau-de-25-euros  2018-06-01 14:13:57
# 1        pierre-jean-villa-saint-joseph-preface-2018  2019-12-30 09:30:29
# 2          pierre-jean-villa-saint-joseph-tilde-2017  2019-12-21 09:00:17
# 3  pierre-jean-villa-croze-hermitage-accroche-coe...  2020-06-26 18:15:03
# 4                  pierre-jean-villa-igp-gamine-2018  2020-01-04 16:36:01
#
#      post_modified_gmt post_content_filtered post_parent  \
# 0  2018-06-01 12:13:57                   NaN         0.0
# 1  2019-12-30 08:30:29                   NaN         0.0
# 2  2019-12-21 08:00:17                   NaN         0.0
# 3  2020-06-26 16:15:03                   NaN         0.0
# 4  2020-01-04 15:36:01                   NaN         0.0
#
#                                                 guid menu_order  post_type  \
# 0  https://www.bottle-neck.fr/?post_type=product&...        0.0    product
# 1  https://www.bottle-neck.fr/?post_type=product&...        0.0    product
# 2  https://www.bottle-neck.fr/?post_type=product&...        0.0    product
# 3  https://www.bottle-neck.fr/?post_type=product&...        0.0    product
# 4  https://www.bottle-neck.fr/?post_type=product&...        0.0    product
#
#   post_mime_type comment_count
# 0            NaN           0.0
# 1            NaN           0.0
# 2            NaN           0.0
# 3            NaN           0.0
# 4            NaN           0.0
#
# [5 rows x 28 columns]

# %%
web.tail(10)
# Out:
#           sku  virtual  downloadable  rating_count  average_rating  \
# 1503    14897        0             0             0             0.0
# 1504    15736        0             0             0             0.0
# 1505    15740        0             0             0             0.0
# 1506    15845        0             0             0             0.0
# 1507    15741        0             0             0             0.0
# 1508    16135        0             0             0             0.0
# 1509    15891        0             0             0             0.0
# 1510    15887        0             0             0             0.0
# 1511  13127-1        0             0             0             0.0
# 1512    16230        0             0             0             0.0
#
#       total_sales tax_status  tax_class  post_author            post_date  \
# 1503          0.0        NaN        NaN          2.0  2020-04-24 21:18:32
# 1504          0.0        NaN        NaN          2.0  2020-04-24 21:32:59
# 1505          0.0        NaN        NaN          2.0  2020-04-25 12:32:17
# 1506          1.0        NaN        NaN          2.0  2020-04-25 12:43:23
# 1507          2.0        NaN        NaN          2.0  2020-04-25 12:49:49
# 1508          5.0        NaN        NaN          2.0  2020-04-25 13:22:38
# 1509          0.0        NaN        NaN          2.0  2020-05-02 14:53:40
# 1510          0.0        NaN        NaN          2.0  2020-05-02 15:00:54
# 1511          0.0        NaN        NaN          2.0  2020-06-09 15:42:04
# 1512          0.0        NaN        NaN          2.0  2020-07-20 11:00:00
#
#       ...                                          post_name  \
# 1503  ...                        gratavinum-priorat-gv5-2011
# 1504  ...                   gratavinum-priorat-2%cf%80r-2017
# 1505  ...            jean-faure-saint-emilion-grand-cru-2015
# 1506  ...    chateau-jean-faure-saint-emilion-grand-cru-2016
# 1507  ...             cedre-de-jean-faure-saint-emilion-2016
# 1508  ...                    mouthes-le-bihan-aime-chai-2015
# 1509  ...         camin-larredya-jurancon-sec-la-virada-2018
# 1510  ...             jamet-cote-rotie-fructus-voluptas-2018
# 1511  ...     clos-du-mont-olivet-chateauneuf-du-pape-2007-2
# 1512  ...  domaine-saint-nicolas-fiefs-vendeens-blanc-les...
#
#             post_modified    post_modified_gmt post_content_filtered  \
# 1503  2020-06-26 15:05:03  2020-06-26 13:05:03                   NaN
# 1504  2020-06-24 11:45:03  2020-06-24 09:45:03                   NaN
# 1505  2020-08-27 11:35:02  2020-08-27 09:35:02                   NaN
# 1506  2020-07-20 17:09:23  2020-07-20 15:09:23                   NaN
# 1507  2020-08-27 15:15:02  2020-08-27 13:15:02                   NaN
# 1508  2020-08-26 17:35:03  2020-08-26 15:35:03                   NaN
# 1509  2020-08-26 17:35:02  2020-08-26 15:35:02                   NaN
# 1510  2020-08-14 18:15:03  2020-08-14 16:15:03                   NaN
# 1511  2020-07-20 17:09:06  2020-07-20 15:09:06                   NaN
# 1512  2020-08-13 10:45:03  2020-08-13 08:45:03                   NaN
#
#      post_parent                                               guid  \
# 1503         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1504         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1505         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1506         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1507         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1508         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1509         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1510         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1511         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1512         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
#
#      menu_order   post_type post_mime_type comment_count
# 1503        0.0  attachment     image/jpeg           0.0
# 1504        0.0  attachment     image/jpeg           0.0
# 1505        0.0  attachment     image/jpeg           0.0
# 1506        0.0  attachment     image/jpeg           0.0
# 1507        0.0  attachment     image/jpeg           0.0
# 1508        0.0  attachment     image/jpeg           0.0
# 1509        0.0  attachment     image/jpeg           0.0
# 1510        0.0  attachment     image/jpeg           0.0
# 1511        0.0  attachment     image/jpeg           0.0
# 1512        0.0  attachment     image/jpeg           0.0
#
# [10 rows x 28 columns]

# %%
web.sample(10)
# Out:
#         sku  virtual  downloadable  rating_count  average_rating  total_sales  \
# 1373  15080        0             0             0             0.0          0.0
# 3     15300        0             0             0             0.0          0.0
# 191   15567        0             0             0             0.0          1.0
# 827   15967        0             0             0             0.0         20.0
# 1362  14692        0             0             0             0.0          0.0
# 485   12496        0             0             0             0.0          0.0
# 719   16046        0             0             0             0.0          0.0
# 119   16322        0             0             0             0.0          0.0
# 960   14485        0             0             0             0.0          5.0
# 1011   9636        0             0             0             0.0          0.0
#
#      tax_status  tax_class  post_author            post_date  ...  \
# 1373        NaN        NaN          2.0  2019-03-19 16:41:40  ...
# 3       taxable        NaN          2.0  2018-02-08 14:08:36  ...
# 191     taxable        NaN          2.0  2018-02-28 15:13:09  ...
# 827         NaN        NaN          2.0  2018-02-12 13:17:53  ...
# 1362        NaN        NaN          2.0  2019-03-19 10:06:47  ...
# 485     taxable        NaN          2.0  2018-09-06 11:17:24  ...
# 719     taxable        NaN          2.0  2020-01-18 10:50:11  ...
# 119     taxable        NaN          2.0  2018-02-15 13:51:32  ...
# 960         NaN        NaN          2.0  2018-02-20 15:52:12  ...
# 1011        NaN        NaN          2.0  2018-03-22 10:44:57  ...
#
#                                               post_name        post_modified  \
# 1373                    saint-estephe-hauts-de-pez-2016  2020-04-25 21:41:28
# 3     pierre-jean-villa-croze-hermitage-accroche-coe...  2020-06-26 18:15:03
# 191            domaine-de-la-tour-du-bandol-en-sol-2017  2020-08-08 09:55:02
# 827   oratoire-saint-martin-cairanne-haut-coustias-2016  2020-08-14 18:35:02
# 1362              fonreaud-bordeaux-blanc-le-cygne-2016  2020-04-25 21:40:31
# 485       chili-de-martino-viejas-tinajas-cinsault-2013  2020-04-24 21:44:41
# 719   domaine-de-la-tour-du-bon-bandol-rouge-saint-f...  2020-08-12 11:45:02
# 119   moulin-gassac-igp-pays-herault-guilhem-rouge-2019  2020-08-26 16:05:03
# 960               domaine-huet-vouvray-le-mont-sec-2017  2020-08-21 12:15:10
# 1011                      whisky-wemyss-the-hive-12-ans  2020-08-19 17:45:03
#
#         post_modified_gmt post_content_filtered post_parent  \
# 1373  2020-04-25 19:41:28                   NaN         0.0
# 3     2020-06-26 16:15:03                   NaN         0.0
# 191   2020-08-08 07:55:02                   NaN         0.0
# 827   2020-08-14 16:35:02                   NaN         0.0
# 1362  2020-04-25 19:40:31                   NaN         0.0
# 485   2020-04-24 19:44:41                   NaN         0.0
# 719   2020-08-12 09:45:02                   NaN         0.0
# 119   2020-08-26 14:05:03                   NaN         0.0
# 960   2020-08-21 10:15:10                   NaN         0.0
# 1011  2020-08-19 15:45:03                   NaN         0.0
#
#                                                    guid menu_order  \
# 1373  https://www.bottle-neck.fr/wp-content/uploads/...        0.0
# 3     https://www.bottle-neck.fr/?post_type=product&...        0.0
# 191   https://www.bottle-neck.fr/?post_type=product&...        0.0
# 827   https://www.bottle-neck.fr/wp-content/uploads/...        0.0
# 1362  https://www.bottle-neck.fr/wp-content/uploads/...        0.0
# 485   https://www.bottle-neck.fr/?post_type=product&...        0.0
# 719   https://www.bottle-neck.fr/?post_type=product&...        0.0
# 119   https://www.bottle-neck.fr/?post_type=product&...        0.0
# 960   https://www.bottle-neck.fr/wp-content/uploads/...        0.0
# 1011  https://www.bottle-neck.fr/wp-content/uploads/...        0.0
#
#        post_type post_mime_type comment_count
# 1373  attachment     image/jpeg           0.0
# 3        product            NaN           0.0
# 191      product            NaN           0.0
# 827   attachment     image/jpeg           0.0
# 1362  attachment     image/jpeg           0.0
# 485      product            NaN           0.0
# 719      product            NaN           0.0
# 119      product            NaN           0.0
# 960   attachment     image/jpeg           0.0
# 1011  attachment     image/jpeg           0.0
#
# [10 rows x 28 columns]

# %%
web.shape
# Out:
# (1513, 28)

# %%
web.dtypes
#booléen : post_author post_type
#INT : SKU total_sales
#date ? post_date, post_modified
# Out:
# sku                       object
# virtual                    int64
# downloadable               int64
# rating_count               int64
# average_rating           float64
# total_sales              float64
# tax_status                object
# tax_class                float64
# post_author              float64
# post_date                 object
# post_date_gmt             object
# post_content             float64
# post_title                object
# post_excerpt              object
# post_status               object
# comment_status            object
# ping_status               object
# post_password            float64
# post_name                 object
# post_modified             object
# post_modified_gmt         object
# post_content_filtered    float64
# post_parent              float64
# guid                      object
# menu_order               float64
# post_type                 object
# post_mime_type            object
# comment_count            float64
# dtype: object

# %%
web.loc[:,"post_name"]
# Out:
# 0                                  bon-cadeau-de-25-euros
# 1             pierre-jean-villa-saint-joseph-preface-2018
# 2               pierre-jean-villa-saint-joseph-tilde-2017
# 3       pierre-jean-villa-croze-hermitage-accroche-coe...
# 4                       pierre-jean-villa-igp-gamine-2018
#                               ...
# 1508                      mouthes-le-bihan-aime-chai-2015
# 1509           camin-larredya-jurancon-sec-la-virada-2018
# 1510               jamet-cote-rotie-fructus-voluptas-2018
# 1511       clos-du-mont-olivet-chateauneuf-du-pape-2007-2
# 1512    domaine-saint-nicolas-fiefs-vendeens-blanc-les...
# Name: post_name, Length: 1513, dtype: object

# %%
web.dtypes.value_counts()
# Out:
# object     15
# float64    10
# int64       3
# Name: count, dtype: int64

# %%
web.isna()
# Out:
#         sku  virtual  downloadable  rating_count  average_rating  total_sales  \
# 0     False    False         False         False           False        False
# 1     False    False         False         False           False        False
# 2     False    False         False         False           False        False
# 3     False    False         False         False           False        False
# 4     False    False         False         False           False        False
# ...     ...      ...           ...           ...             ...          ...
# 1508  False    False         False         False           False        False
# 1509  False    False         False         False           False        False
# 1510  False    False         False         False           False        False
# 1511  False    False         False         False           False        False
# 1512  False    False         False         False           False        False
#
#       tax_status  tax_class  post_author  post_date  ...  post_name  \
# 0          False       True        False      False  ...      False
# 1          False       True        False      False  ...      False
# 2          False       True        False      False  ...      False
# 3          False       True        False      False  ...      False
# 4          False       True        False      False  ...      False
# ...          ...        ...          ...        ...  ...        ...
# 1508        True       True        False      False  ...      False
# 1509        True       True        False      False  ...      False
# 1510        True       True        False      False  ...      False
# 1511        True       True        False      False  ...      False
# 1512        True       True        False      False  ...      False
#
#       post_modified  post_modified_gmt  post_content_filtered  post_parent  \
# 0             False              False                   True        False
# 1             False              False                   True        False
# 2             False              False                   True        False
# 3             False              False                   True        False
# 4             False              False                   True        False
# ...             ...                ...                    ...          ...
# 1508          False              False                   True        False
# 1509          False              False                   True        False
# 1510          False              False                   True        False
# 1511          False              False                   True        False
# 1512          False              False                   True        False
#
#        guid  menu_order  post_type  post_mime_type  comment_count
# 0     False       False      False            True          False
# 1     False       False      False            True          False
# 2     False       False      False            True          False
# 3     False       False      False            True          False
# 4     False       False      False            True          False
# ...     ...         ...        ...             ...            ...
# 1508  False       False      False           False          False
# 1509  False       False      False           False          False
# 1510  False       False      False           False          False
# 1511  False       False      False           False          False
# 1512  False       False      False           False          False
#
# [1513 rows x 28 columns]

# %%
web.isna().sum()
# Out:
# sku                        85
# virtual                     0
# downloadable                0
# rating_count                0
# average_rating             83
# total_sales                83
# tax_status                797
# tax_class                1513
# post_author                83
# post_date                  83
# post_date_gmt              83
# post_content             1513
# post_title                 83
# post_excerpt              797
# post_status                83
# comment_status             83
# ping_status                83
# post_password            1513
# post_name                  83
# post_modified              83
# post_modified_gmt          83
# post_content_filtered    1513
# post_parent                83
# guid                       83
# menu_order                 83
# post_type                  83
# post_mime_type            799
# comment_count              83
# dtype: int64

# %%
web.isna().mean().round(2)
# Out:
# sku                      0.06
# virtual                  0.00
# downloadable             0.00
# rating_count             0.00
# average_rating           0.05
# total_sales              0.05
# tax_status               0.53
# tax_class                1.00
# post_author              0.05
# post_date                0.05
# post_date_gmt            0.05
# post_content             1.00
# post_title               0.05
# post_excerpt             0.53
# post_status              0.05
# comment_status           0.05
# ping_status              0.05
# post_password            1.00
# post_name                0.05
# post_modified            0.05
# post_modified_gmt        0.05
# post_content_filtered    1.00
# post_parent              0.05
# guid                     0.05
# menu_order               0.05
# post_type                0.05
# post_mime_type           0.53
# comment_count            0.05
# dtype: float64

# %%
web.isna().mean(axis=1).round(2).sort_values(ascending = False)
# Out:
# 756    0.89
# 455    0.89
# 523    0.89
# 529    0.89
# 598    0.89
#        ...
# 498    0.18
# 497    0.18
# 496    0.18
# 495    0.18
# 0      0.18
# Length: 1513, dtype: float64

# %%
hmweb = web.isna().mean(axis=1).round(2).sort_values(ascending = False).value_counts()
hmweb
# Out:
# 0.21    716
# 0.18    714
# 0.89     83
# Name: count, dtype: int64

# %%
sns.heatmap(web.isna())
# Out:
# <Axes: >

# %%
web.nunique()
#Main / PK : guid ?
#FK : post_name & SKU ?
#web.drop(columns='xx')
#SUPPR columns virtual downloadable  rating_count average_rating tax_status tax_class post_date_gmt post_modified_gmt post_content post_status comment_status ping_status post_password post_content_filtered post_parent menu_order post_mime_type comment_count
# Out:
# sku                       714
# virtual                     1
# downloadable                1
# rating_count                1
# average_rating              1
# total_sales                41
# tax_status                  1
# tax_class                   0
# post_author                 2
# post_date                 716
# post_date_gmt             716
# post_content                0
# post_title                713
# post_excerpt              679
# post_status                 1
# comment_status              1
# ping_status                 1
# post_password               0
# post_name                 716
# post_modified             589
# post_modified_gmt         589
# post_content_filtered       0
# post_parent                 1
# guid                     1430
# menu_order                  1
# post_type                   2
# post_mime_type              1
# comment_count               1
# dtype: int64

# %% [markdown]
# #Start fichier CSV Liaison

# %%
liaison =pd.read_csv("../data/Liaison P6.csv")
liaison.head()
# Out:
#    product_id id_web = SKU
# 0        3847        15298
# 1        3849        15296
# 2        3850        15300
# 3        4032        19814
# 4        4039        19815

# %%
liaison.tail()
# Out:
#      product_id id_web = SKU
# 820        7203          NaN
# 821        7204          NaN
# 822        7247      13127-1
# 823        7329      14680-1
# 824        7338        16230

# %%
liaison.sample(20)
# Out:
#      product_id id_web = SKU
# 382        4795         3568
# 620        5807        15471
# 198        4301        16553
# 73         4142        11641
# 562        5618        15921
# 767        6869          NaN
# 224        4399        12640
# 782        6908          NaN
# 289        4656        10814
# 528        5523        15862
# 261        4615        16186
# 87         4158        16093
# 746        6622        15205
# 790        7010          NaN
# 647        5912        15227
# 691        6105        14090
# 160        4248        15033
# 129        4207        16023
# 184        4278          NaN
# 548        5570        14730

# %%
liaison.shape
# Out:
# (825, 2)

# %%
liaison.dtypes
# Out:
# product_id       int64
# id_web = SKU    object
# dtype: object

# %%
liaison.isna().sum()
# Out:
# product_id       0
# id_web = SKU    91
# dtype: int64

# %%
liaison.isna().mean().round(2)
# Out:
# product_id      0.00
# id_web = SKU    0.11
# dtype: float64

# %%
liaison.nunique()
#PK : 825
#attention bon-cadeau-25-euros
# Out:
# product_id      825
# id_web = SKU    734
# dtype: int64

# %% [markdown]
# CLEANING

# %%
#SUPPR columns virtual downloadable  rating_count average_rating tax_status tax_class post_date_gmt post_modified_gmt post_content post_status comment_status ping_status post_password post_content_filtered post_parent menu_order post_mime_type comment_count

# %%
web.drop(columns=['virtual','downloadable','rating_count','average_rating','tax_status','tax_class','post_date_gmt','post_modified_gmt','post_content',
                  'post_status','comment_status','ping_status','post_password','post_content_filtered','post_parent','menu_order','post_mime_type',
                  'comment_count'])
# Out:
#                       sku  total_sales  post_author            post_date  \
# 0     bon-cadeau-25-euros         10.0          1.0  2018-06-01 13:53:46
# 1                   15298          6.0          2.0  2018-02-08 12:58:52
# 2                   15296          0.0          2.0  2018-02-08 13:49:41
# 3                   15300          0.0          2.0  2018-02-08 14:08:36
# 4                   19814          3.0          2.0  2018-02-09 14:01:05
# ...                   ...          ...          ...                  ...
# 1508                16135          5.0          2.0  2020-04-25 13:22:38
# 1509                15891          0.0          2.0  2020-05-02 14:53:40
# 1510                15887          0.0          2.0  2020-05-02 15:00:54
# 1511              13127-1          0.0          2.0  2020-06-09 15:42:04
# 1512                16230          0.0          2.0  2020-07-20 11:00:00
#
#                                              post_title  \
# 0                                     Bon cadeau de 25€
# 1           Pierre Jean Villa Saint-Joseph Préface 2018
# 2       Pierre Jean Villa Saint-Joseph Rouge Tildé 2017
# 3     Pierre Jean Villa Crozes-Hermitage Accroche Co...
# 4     Pierre Jean Villa IGP Collines Rhodaniennes Ga...
# ...                                                 ...
# 1508   Mouthes Le Bihan Côtes de Duras L'Aimé Chai 2015
# 1509         Camin Larredya Jurançon Sec La Virada 2018
# 1510     Domaine Jamet Côte Rôtie Fructus Voluptas 2018
# 1511       Clos du Mont-Olivet Châteauneuf-du-Pape 2007
# 1512  Domaine Saint-Nicolas Vin de France Blanc Les ...
#
#                                            post_excerpt  \
# 0     <span style="color: #a85253;"><strong>Parlons ...
# 1     Il exhale un nez subtil, racé avec du poivre f...
# 2     Les vieilles vignes lui apportent une rare pro...
# 3     Dentelle de fruit de jeunes syrah, aux tanins ...
# 4     Gamine représente tout le fruité et la gourman...
# ...                                                 ...
# 1508                                                NaN
# 1509                                                NaN
# 1510                                                NaN
# 1511                                                NaN
# 1512                                                NaN
#
#                                               post_name        post_modified  \
# 0                                bon-cadeau-de-25-euros  2018-06-01 14:13:57
# 1           pierre-jean-villa-saint-joseph-preface-2018  2019-12-30 09:30:29
# 2             pierre-jean-villa-saint-joseph-tilde-2017  2019-12-21 09:00:17
# 3     pierre-jean-villa-croze-hermitage-accroche-coe...  2020-06-26 18:15:03
# 4                     pierre-jean-villa-igp-gamine-2018  2020-01-04 16:36:01
# ...                                                 ...                  ...
# 1508                    mouthes-le-bihan-aime-chai-2015  2020-08-26 17:35:03
# 1509         camin-larredya-jurancon-sec-la-virada-2018  2020-08-26 17:35:02
# 1510             jamet-cote-rotie-fructus-voluptas-2018  2020-08-14 18:15:03
# 1511     clos-du-mont-olivet-chateauneuf-du-pape-2007-2  2020-07-20 17:09:06
# 1512  domaine-saint-nicolas-fiefs-vendeens-blanc-les...  2020-08-13 10:45:03
#
#                                                    guid   post_type
# 0     https://www.bottle-neck.fr/?post_type=product&...     product
# 1     https://www.bottle-neck.fr/?post_type=product&...     product
# 2     https://www.bottle-neck.fr/?post_type=product&...     product
# 3     https://www.bottle-neck.fr/?post_type=product&...     product
# 4     https://www.bottle-neck.fr/?post_type=product&...     product
# ...                                                 ...         ...
# 1508  https://www.bottle-neck.fr/wp-content/uploads/...  attachment
# 1509  https://www.bottle-neck.fr/wp-content/uploads/...  attachment
# 1510  https://www.bottle-neck.fr/wp-content/uploads/...  attachment
# 1511  https://www.bottle-neck.fr/wp-content/uploads/...  attachment
# 1512  https://www.bottle-neck.fr/wp-content/uploads/...  attachment
#
# [1513 rows x 10 columns]

# %%
#type Boléen : onsale_web / stock_status = erp['onsale_web','stock_status'].astype(bool)
erp['onsale_web']= erp['onsale_web'].astype(bool)

# %%
erp["stock_status"]= erp['stock_status'].astype(bool)
print(erp.dtypes)
# Out:
# product_id         int64
# onsale_web          bool
# price             object
# stock_quantity     int64
# stock_status        bool
# dtype: object

# %%
erp.price = erp.price.str.replace(",",".")

# %%
erp
# Out:
#      product_id  onsale_web price  stock_quantity  stock_status
# 0          3847        True  24.2               0          True
# 1          3849        True  34.3               0          True
# 2          3850        True  20.8               0          True
# 3          4032        True  14.1               0          True
# 4          4039        True    46               0          True
# ..          ...         ...   ...             ...           ...
# 820        7203       False    45              30          True
# 821        7204       False    45               9          True
# 822        7247        True  54.8              23          True
# 823        7329       False  26.5              14          True
# 824        7338        True  16.3              45          True
#
# [825 rows x 5 columns]

# %%
 erp["price"] = erp.price.astype(float)
print(erp.dtypes)
# Out:
# product_id          int64
# onsale_web           bool
# price             float64
# stock_quantity      int64
# stock_status         bool
# dtype: object

# %%
#booléen : post_author post_type
#INT : SKU total_sales
web["post_type"] = web["post_type"].astype(bool)
web["post_author"] = web["post_author"].astype(bool)
print(web.dtypes)
# Out:
# sku                       object
# virtual                    int64
# downloadable               int64
# rating_count               int64
# average_rating           float64
# total_sales              float64
# tax_status                object
# tax_class                float64
# post_author                 bool
# post_date                 object
# post_date_gmt             object
# post_content             float64
# post_title                object
# post_excerpt              object
# post_status               object
# comment_status            object
# ping_status               object
# post_password            float64
# post_name                 object
# post_modified             object
# post_modified_gmt         object
# post_content_filtered    float64
# post_parent              float64
# guid                      object
# menu_order               float64
# post_type                   bool
# post_mime_type            object
# comment_count            float64
# dtype: object

# %%
web['total_sales'].fillna(0, inplace=True)
web['total_sales'] = web['total_sales'].astype(int)
print(web.dtypes)
# Out:
# sku                       object
# virtual                    int64
# downloadable               int64
# rating_count               int64
# average_rating           float64
# total_sales                int32
# tax_status                object
# tax_class                float64
# post_author                 bool
# post_date                 object
# post_date_gmt             object
# post_content             float64
# post_title                object
# post_excerpt              object
# post_status               object
# comment_status            object
# ping_status               object
# post_password            float64
# post_name                 object
# post_modified             object
# post_modified_gmt         object
# post_content_filtered    float64
# post_parent              float64
# guid                      object
# menu_order               float64
# post_type                   bool
# post_mime_type            object
# comment_count            float64
# dtype: object
# C:\Users\josse\AppData\Local\Temp\ipykernel_9268\353255444.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   web['total_sales'].fillna(0, inplace=True)

# %%
#millésime=INT carat_vin
carat_vin['Millésime'].fillna(0, inplace=True)
carat_vin['Millésime'] = carat_vin['Millésime'].astype(int)
print(carat_vin.dtypes)
# Out:
# post_name                          object
# poids                              object
# Région                             object
# Domaine                            object
# Appellation                        object
# Couleur                            object
# Cépage (decider avec ou sans %)    object
# Millésime                           int32
# Garde                              object
# Contenance                         object
# Degré d'alcool                     object
# Température dégustation            object
# Alliance mets                      object
# dtype: object
# C:\Users\josse\AppData\Local\Temp\ipykernel_9268\2477921544.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   carat_vin['Millésime'].fillna(0, inplace=True)

# %%
# Remplacer les valeurs non numériques par NaN
web['sku'] = pd.to_numeric(web['sku'], errors='coerce')

# Afficher les types de données après la conversion
print(web.dtypes)
# Out:
# sku                      float64
# virtual                    int64
# downloadable               int64
# rating_count               int64
# average_rating           float64
# total_sales                int32
# tax_status                object
# tax_class                float64
# post_author                 bool
# post_date                 object
# post_date_gmt             object
# post_content             float64
# post_title                object
# post_excerpt              object
# post_status               object
# comment_status            object
# ping_status               object
# post_password            float64
# post_name                 object
# post_modified             object
# post_modified_gmt         object
# post_content_filtered    float64
# post_parent              float64
# guid                      object
# menu_order               float64
# post_type                   bool
# post_mime_type            object
# comment_count            float64
# dtype: object

# %%
print(web)
# Out:
#           sku  virtual  downloadable  rating_count  average_rating  \
# 0         NaN        0             0             0             0.0
# 1     15298.0        0             0             0             0.0
# 2     15296.0        0             0             0             0.0
# 3     15300.0        0             0             0             0.0
# 4     19814.0        0             0             0             0.0
# ...       ...      ...           ...           ...             ...
# 1508  16135.0        0             0             0             0.0
# 1509  15891.0        0             0             0             0.0
# 1510  15887.0        0             0             0             0.0
# 1511      NaN        0             0             0             0.0
# 1512  16230.0        0             0             0             0.0
#
#       total_sales tax_status  tax_class  post_author            post_date  \
# 0              10    taxable        NaN         True  2018-06-01 13:53:46
# 1               6    taxable        NaN         True  2018-02-08 12:58:52
# 2               0    taxable        NaN         True  2018-02-08 13:49:41
# 3               0    taxable        NaN         True  2018-02-08 14:08:36
# 4               3    taxable        NaN         True  2018-02-09 14:01:05
# ...           ...        ...        ...          ...                  ...
# 1508            5        NaN        NaN         True  2020-04-25 13:22:38
# 1509            0        NaN        NaN         True  2020-05-02 14:53:40
# 1510            0        NaN        NaN         True  2020-05-02 15:00:54
# 1511            0        NaN        NaN         True  2020-06-09 15:42:04
# 1512            0        NaN        NaN         True  2020-07-20 11:00:00
#
#       ...                                          post_name  \
# 0     ...                             bon-cadeau-de-25-euros
# 1     ...        pierre-jean-villa-saint-joseph-preface-2018
# 2     ...          pierre-jean-villa-saint-joseph-tilde-2017
# 3     ...  pierre-jean-villa-croze-hermitage-accroche-coe...
# 4     ...                  pierre-jean-villa-igp-gamine-2018
# ...   ...                                                ...
# 1508  ...                    mouthes-le-bihan-aime-chai-2015
# 1509  ...         camin-larredya-jurancon-sec-la-virada-2018
# 1510  ...             jamet-cote-rotie-fructus-voluptas-2018
# 1511  ...     clos-du-mont-olivet-chateauneuf-du-pape-2007-2
# 1512  ...  domaine-saint-nicolas-fiefs-vendeens-blanc-les...
#
#             post_modified    post_modified_gmt post_content_filtered  \
# 0     2018-06-01 14:13:57  2018-06-01 12:13:57                   NaN
# 1     2019-12-30 09:30:29  2019-12-30 08:30:29                   NaN
# 2     2019-12-21 09:00:17  2019-12-21 08:00:17                   NaN
# 3     2020-06-26 18:15:03  2020-06-26 16:15:03                   NaN
# 4     2020-01-04 16:36:01  2020-01-04 15:36:01                   NaN
# ...                   ...                  ...                   ...
# 1508  2020-08-26 17:35:03  2020-08-26 15:35:03                   NaN
# 1509  2020-08-26 17:35:02  2020-08-26 15:35:02                   NaN
# 1510  2020-08-14 18:15:03  2020-08-14 16:15:03                   NaN
# 1511  2020-07-20 17:09:06  2020-07-20 15:09:06                   NaN
# 1512  2020-08-13 10:45:03  2020-08-13 08:45:03                   NaN
#
#      post_parent                                               guid  \
# 0            0.0  https://www.bottle-neck.fr/?post_type=product&...
# 1            0.0  https://www.bottle-neck.fr/?post_type=product&...
# 2            0.0  https://www.bottle-neck.fr/?post_type=product&...
# 3            0.0  https://www.bottle-neck.fr/?post_type=product&...
# 4            0.0  https://www.bottle-neck.fr/?post_type=product&...
# ...          ...                                                ...
# 1508         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1509         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1510         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1511         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1512         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
#
#      menu_order  post_type post_mime_type comment_count
# 0           0.0       True            NaN           0.0
# 1           0.0       True            NaN           0.0
# 2           0.0       True            NaN           0.0
# 3           0.0       True            NaN           0.0
# 4           0.0       True            NaN           0.0
# ...         ...        ...            ...           ...
# 1508        0.0       True     image/jpeg           0.0
# 1509        0.0       True     image/jpeg           0.0
# 1510        0.0       True     image/jpeg           0.0
# 1511        0.0       True     image/jpeg           0.0
# 1512        0.0       True     image/jpeg           0.0
#
# [1513 rows x 28 columns]

# %%
# Remplacer les valeurs non numériques par NaN
liaison['id_web = SKU'] = pd.to_numeric(liaison['id_web = SKU'], errors='coerce')

# Afficher les types de données après la conversion
print(liaison.dtypes)
# Out:
# product_id        int64
# id_web = SKU    float64
# dtype: object

# %%
#plutôt qu'un drop, ne devrais-je pas utiliser del pour supprimer vraiment les colonnes ? NON
#'sku' web je l'ai rtransformé en float ainsi que 'id-web=sku' liaison (pas de suppression de ligne)
#OK ?

# %% [markdown]
# MERGE

# %%
liaison.columns=['product_id','sku']

# %%
liaison
# Out:
#      product_id    sku
# 0          3847  15298
# 1          3849  15296
# 2          3850  15300
# 3          4032  19814
# 4          4039  19815
# ..          ...    ...
# 820        7203     -1
# 821        7204     -1
# 822        7247     -1
# 823        7329     -1
# 824        7338  16230
#
# [825 rows x 2 columns]

# %%
liaison['sku'].fillna(-1,inplace=True)
# Out:
# C:\Users\josse\AppData\Local\Temp\ipykernel_9268\1390406215.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   liaison['sku'].fillna(-1,inplace=True)

# %%
liaison = liaison.astype(int)

# %%
liaison.dtypes
# Out:
# product_id    int32
# sku           int32
# dtype: object

# %%
merged_erp_liaison = pd.merge(erp, liaison, on='product_id', how='outer')
display(merged_erp_liaison)
# Out:
#      product_id  onsale_web  price  stock_quantity  stock_status    sku
# 0          3847        True   24.2               0          True  15298
# 1          3849        True   34.3               0          True  15296
# 2          3850        True   20.8               0          True  15300
# 3          4032        True   14.1               0          True  19814
# 4          4039        True   46.0               0          True  19815
# ..          ...         ...    ...             ...           ...    ...
# 820        7203       False   45.0              30          True     -1
# 821        7204       False   45.0               9          True     -1
# 822        7247        True   54.8              23          True     -1
# 823        7329       False   26.5              14          True     -1
# 824        7338        True   16.3              45          True  16230
#
# [825 rows x 6 columns]

# %%
merged_erp_web = pd.merge(merged_erp_liaison, web, on='sku', how='outer')

# %%
web
# Out:
#           sku  virtual  downloadable  rating_count  average_rating  \
# 0         NaN        0             0             0             0.0
# 1     15298.0        0             0             0             0.0
# 2     15296.0        0             0             0             0.0
# 3     15300.0        0             0             0             0.0
# 4     19814.0        0             0             0             0.0
# ...       ...      ...           ...           ...             ...
# 1508  16135.0        0             0             0             0.0
# 1509  15891.0        0             0             0             0.0
# 1510  15887.0        0             0             0             0.0
# 1511      NaN        0             0             0             0.0
# 1512  16230.0        0             0             0             0.0
#
#       total_sales tax_status  tax_class  post_author            post_date  \
# 0              10    taxable        NaN         True  2018-06-01 13:53:46
# 1               6    taxable        NaN         True  2018-02-08 12:58:52
# 2               0    taxable        NaN         True  2018-02-08 13:49:41
# 3               0    taxable        NaN         True  2018-02-08 14:08:36
# 4               3    taxable        NaN         True  2018-02-09 14:01:05
# ...           ...        ...        ...          ...                  ...
# 1508            5        NaN        NaN         True  2020-04-25 13:22:38
# 1509            0        NaN        NaN         True  2020-05-02 14:53:40
# 1510            0        NaN        NaN         True  2020-05-02 15:00:54
# 1511            0        NaN        NaN         True  2020-06-09 15:42:04
# 1512            0        NaN        NaN         True  2020-07-20 11:00:00
#
#       ...                                          post_name  \
# 0     ...                             bon-cadeau-de-25-euros
# 1     ...        pierre-jean-villa-saint-joseph-preface-2018
# 2     ...          pierre-jean-villa-saint-joseph-tilde-2017
# 3     ...  pierre-jean-villa-croze-hermitage-accroche-coe...
# 4     ...                  pierre-jean-villa-igp-gamine-2018
# ...   ...                                                ...
# 1508  ...                    mouthes-le-bihan-aime-chai-2015
# 1509  ...         camin-larredya-jurancon-sec-la-virada-2018
# 1510  ...             jamet-cote-rotie-fructus-voluptas-2018
# 1511  ...     clos-du-mont-olivet-chateauneuf-du-pape-2007-2
# 1512  ...  domaine-saint-nicolas-fiefs-vendeens-blanc-les...
#
#             post_modified    post_modified_gmt post_content_filtered  \
# 0     2018-06-01 14:13:57  2018-06-01 12:13:57                   NaN
# 1     2019-12-30 09:30:29  2019-12-30 08:30:29                   NaN
# 2     2019-12-21 09:00:17  2019-12-21 08:00:17                   NaN
# 3     2020-06-26 18:15:03  2020-06-26 16:15:03                   NaN
# 4     2020-01-04 16:36:01  2020-01-04 15:36:01                   NaN
# ...                   ...                  ...                   ...
# 1508  2020-08-26 17:35:03  2020-08-26 15:35:03                   NaN
# 1509  2020-08-26 17:35:02  2020-08-26 15:35:02                   NaN
# 1510  2020-08-14 18:15:03  2020-08-14 16:15:03                   NaN
# 1511  2020-07-20 17:09:06  2020-07-20 15:09:06                   NaN
# 1512  2020-08-13 10:45:03  2020-08-13 08:45:03                   NaN
#
#      post_parent                                               guid  \
# 0            0.0  https://www.bottle-neck.fr/?post_type=product&...
# 1            0.0  https://www.bottle-neck.fr/?post_type=product&...
# 2            0.0  https://www.bottle-neck.fr/?post_type=product&...
# 3            0.0  https://www.bottle-neck.fr/?post_type=product&...
# 4            0.0  https://www.bottle-neck.fr/?post_type=product&...
# ...          ...                                                ...
# 1508         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1509         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1510         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1511         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
# 1512         0.0  https://www.bottle-neck.fr/wp-content/uploads/...
#
#      menu_order  post_type post_mime_type comment_count
# 0           0.0       True            NaN           0.0
# 1           0.0       True            NaN           0.0
# 2           0.0       True            NaN           0.0
# 3           0.0       True            NaN           0.0
# 4           0.0       True            NaN           0.0
# ...         ...        ...            ...           ...
# 1508        0.0       True     image/jpeg           0.0
# 1509        0.0       True     image/jpeg           0.0
# 1510        0.0       True     image/jpeg           0.0
# 1511        0.0       True     image/jpeg           0.0
# 1512        0.0       True     image/jpeg           0.0
#
# [1513 rows x 28 columns]

# %%
merged_erp_web
# Out:
#       product_id onsale_web  price  stock_quantity stock_status  sku  virtual  \
# 0         4055.0      False   86.1             0.0         True -1.0      NaN
# 1         4090.0      False   73.0             0.0         True -1.0      NaN
# 2         4092.0      False   47.0             0.0         True -1.0      NaN
# 3         4195.0      False   14.1             0.0         True -1.0      NaN
# 4         4209.0      False   73.5             0.0         True -1.0      NaN
# ...          ...        ...    ...             ...          ...  ...      ...
# 1621         NaN        NaN    NaN             NaN          NaN  NaN      0.0
# 1622         NaN        NaN    NaN             NaN          NaN  NaN      0.0
# 1623         NaN        NaN    NaN             NaN          NaN  NaN      0.0
# 1624         NaN        NaN    NaN             NaN          NaN  NaN      0.0
# 1625         NaN        NaN    NaN             NaN          NaN  NaN      0.0
#
#       downloadable  rating_count  average_rating  ...  \
# 0              NaN           NaN             NaN  ...
# 1              NaN           NaN             NaN  ...
# 2              NaN           NaN             NaN  ...
# 3              NaN           NaN             NaN  ...
# 4              NaN           NaN             NaN  ...
# ...            ...           ...             ...  ...
# 1621           0.0           0.0             NaN  ...
# 1622           0.0           0.0             NaN  ...
# 1623           0.0           0.0             0.0  ...
# 1624           0.0           0.0             0.0  ...
# 1625           0.0           0.0             0.0  ...
#
#                                            post_name        post_modified  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
# ...                                              ...                  ...
# 1621                                             NaN                  NaN
# 1622                                             NaN                  NaN
# 1623  clos-du-mont-olivet-chateauneuf-du-pape-2007-2  2020-07-20 17:09:06
# 1624                          bon-cadeau-de-25-euros  2018-06-01 14:13:57
# 1625  clos-du-mont-olivet-chateauneuf-du-pape-2007-2  2020-07-20 17:09:06
#
#         post_modified_gmt post_content_filtered post_parent  \
# 0                     NaN                   NaN         NaN
# 1                     NaN                   NaN         NaN
# 2                     NaN                   NaN         NaN
# 3                     NaN                   NaN         NaN
# 4                     NaN                   NaN         NaN
# ...                   ...                   ...         ...
# 1621                  NaN                   NaN         NaN
# 1622                  NaN                   NaN         NaN
# 1623  2020-07-20 15:09:06                   NaN         0.0
# 1624  2018-06-01 12:13:57                   NaN         0.0
# 1625  2020-07-20 15:09:06                   NaN         0.0
#
#                                                    guid  menu_order post_type  \
# 0                                                   NaN         NaN       NaN
# 1                                                   NaN         NaN       NaN
# 2                                                   NaN         NaN       NaN
# 3                                                   NaN         NaN       NaN
# 4                                                   NaN         NaN       NaN
# ...                                                 ...         ...       ...
# 1621                                                NaN         NaN      True
# 1622                                                NaN         NaN      True
# 1623  https://www.bottle-neck.fr/?post_type=product&...         0.0      True
# 1624  https://www.bottle-neck.fr/wp-content/uploads/...         0.0      True
# 1625  https://www.bottle-neck.fr/wp-content/uploads/...         0.0      True
#
#      post_mime_type comment_count
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
# ...             ...           ...
# 1621            NaN           NaN
# 1622            NaN           NaN
# 1623            NaN           0.0
# 1624     image/jpeg           0.0
# 1625     image/jpeg           0.0
#
# [1626 rows x 33 columns]

# %%
merged_erp_liaison
# Out:
#      product_id  onsale_web  price  stock_quantity  stock_status    sku
# 0          3847        True   24.2               0          True  15298
# 1          3849        True   34.3               0          True  15296
# 2          3850        True   20.8               0          True  15300
# 3          4032        True   14.1               0          True  19814
# 4          4039        True   46.0               0          True  19815
# ..          ...         ...    ...             ...           ...    ...
# 820        7203       False   45.0              30          True     -1
# 821        7204       False   45.0               9          True     -1
# 822        7247        True   54.8              23          True     -1
# 823        7329       False   26.5              14          True     -1
# 824        7338        True   16.3              45          True  16230
#
# [825 rows x 6 columns]

# %%
# Fusionner erp et web sur la colonne 'product_id'
merged_erp_liaison = pd.merge(erp, liaison, on='product_id', how='outer')

# Fusionner le résultat précédent avec le DataFrame liaison sur la colonne 'id_web = SKU'
merged_erp_web = pd.merge(merged_erp_liaison, web, on='id_web = SKU', how='outer')

# Fusionner le résultat précédent avec le DataFrame carat_vin sur la colonne 'id_web = SKU'
allin = pd.merge(merged_erp_web_liaison, carat_vin, on='post_name', how='outer')

# Afficher le résultat
display(allin)
